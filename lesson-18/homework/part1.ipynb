# %%
import pandas as pd
import sqlite3 as sql3
import csv

# %%
with sql3.connect('../data/chinook.db') as connection:
    df_customers = pd.read_sql(
        'SELECT * FROM customers',
        con=connection
    )
df_customers.head(10)
# Out:
#    CustomerId  FirstName     LastName  \
# 0           1       Luís    Gonçalves
# 1           2     Leonie       Köhler
# 2           3   François     Tremblay
# 3           4      Bjørn       Hansen
# 4           5  František  Wichterlová
# 5           6     Helena         Holý
# 6           7     Astrid       Gruber
# 7           8       Daan      Peeters
# 8           9       Kara      Nielsen
# 9          10    Eduardo      Martins
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                  JetBrains s.r.o.
# 5                                              None
# 6                                              None
# 7                                              None
# 8                                              None
# ...

# %%
df_iris = pd.read_json('../data/iris.json')
print(df_iris.shape, df_iris.columns)
# Out:
# (150, 5) Index(['sepalLength', 'sepalWidth', 'petalLength', 'petalWidth', 'species'], dtype='object')

# %%
df_titanic = pd.read_excel('../data/titanic.xlsx', sheet_name='Sheet1')
df_titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_parquet = pd.read_parquet('../data/flights')
df_parquet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6729125 entries, 0 to 6729124
# Columns: 109 entries, Year to Div5TailNum
# dtypes: object(109)
# memory usage: 5.5+ GB

# %%
df_movie = pd.read_csv('../data/movie.csv')
df_movie.sample(10)
# Out:
#       color   director_name  num_critic_for_reviews  duration  \
# 349   Color   John Lasseter                   191.0      82.0
# 892   Color  John Singleton                   160.0      99.0
# 3988  Color     Adam Marcus                   112.0      91.0
# 480   Color    Steven Brill                    87.0      90.0
# 794   Color   Walter Salles                   196.0     103.0
# 3156  Color    Bob Odenkirk                    51.0      93.0
# 4255  Color  Jehane Noujaim                    68.0     108.0
# 493   Color   Kevin Costner                    79.0     177.0
# 2340  Color    Lee Tamahori                   167.0     109.0
# 2353  Color  Emile Ardolino                    10.0      92.0
#
#       director_facebook_likes  actor_3_facebook_likes          actor_2_name  \
# 349                     487.0                   967.0     John Ratzenberger
# 892                     309.0                   577.0      Vanessa Williams
# ...

# %%
with open('../data/movie.csv') as f:
    reader = csv.reader(f)
    header = next(reader)
    header_list = list(header)
print(header_list[1])
# Out:
# director_name
